# %%
from yahoo_fin.stock_info import get_data
from datetime import date
import plotly.express as px
import pandas as pd
import numpy as np

today = date.today()
spy = get_data("spy", start_date="01/03/2015", end_date=today, index_as_date = True, interval="1d")
xle = get_data("xle", start_date="01/03/2015", end_date=today, index_as_date = True, interval="1d")
gold = get_data("GLD", start_date="01/03/2015", end_date=today, index_as_date = True, interval="1d")

# %%
fig = px.line(spy['close'], labels={ 'close' : 'SPY CLOSE'})
fig.show()

# %%
gold
# Out:
#                   open        high         low       close    adjclose  \
# 2015-01-05  114.779999  116.000000  114.730003  115.800003  115.800003
# 2015-01-06  116.220001  117.500000  115.800003  117.120003  117.120003
# 2015-01-07  116.470001  116.879997  116.169998  116.430000  116.430000
# 2015-01-08  116.449997  116.870003  115.849998  115.940002  115.940002
# 2015-01-09  116.510002  117.339996  116.500000  117.260002  117.260002
# ...                ...         ...         ...         ...         ...
# 2021-04-29  165.580002  166.259995  164.470001  166.220001  166.220001
# 2021-04-30  165.860001  166.000000  165.240005  165.660004  165.660004
# 2021-05-03  167.610001  168.429993  167.410004  167.809998  167.809998
# 2021-05-04  167.690002  168.550003  165.500000  166.580002  166.580002
# 2021-05-05  166.630005  167.309998  166.630005  167.270004  167.270004
#
#               volume ticker
# 2015-01-05   8177400    GLD
# 2015-01-06  11238300    GLD
# 2015-01-07   6434200    GLD
# 2015-01-08   7033700    GLD
# 2015-01-09   7962900    GLD
# ...              ...    ...
# 2021-04-29   9067600    GLD
# 2021-04-30   6247800    GLD
# 2021-05-03   9014700    GLD
# 2021-05-04  10267400    GLD
# 2021-05-05   3169300    GLD
#
# [1595 rows x 7 columns]

# %%
dxy = get_data("dxy", start_date="01/03/2015", end_date=today, index_as_date = True, interval="1d")
dxy['close'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:>
